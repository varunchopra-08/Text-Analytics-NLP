# %% [raw]
# ##NLP Pipeline
# #NLP is a set of steps followed to build an end to end nlp software
# Consists of following steps:
#
# 1.Data Acquisition
# 2.Text Preparation
#     Text Cleanup
#     Basic Preprocessing
#     Advance Preprocessing
# 3.Feature Engineering - converting into correct formats ef -bag of word,TF-IDF, wordtovec
# 4.Modelling
#     Model Building
#     Evaluation
# 5.Deployement
#     Deployement
#     Monitoring
#     Model Update
#
# #But it's not universal
# #Deep Learning pipelines are slightly different
# #Pipeline is non linear

# %% [raw]
# ##Data Acquisition
#
#  3 posibilities - Data vailible to you -on table -data engineering -data augumentation
#                 Data availible to others externally
#                 No data availible

# %% [raw]
# Data augumention - replace word with syonyms
#                 bigram flip - combination of two words
#                 back translate
#                 addition of noise

# %% [raw]
# others- public dataset
#         web scraping - beautiful soup
#         API - rapidapi.com lib:requests , data:json
#         pdf
#         image
#         audio

# %% [raw]
# ##Text Preparation - Cleanup , Basic Preprocessing ,  Advance Preprocessing
# #cleaning - html tag cleaning , emoji-text_encode ,spelling check
# #Basic Preprocessing - basic-tokenization -sentence ,word , optional-stop word removal , stemming/lemmitization, removing digits , lowercasing, language detection

# %% [markdown]
# ##Tokenization-sentence
# ![image.png](attachment:8409c642-938b-4284-bbfa-ea55cabbeca6.png)
# ##tokenization-word
# ![image.png](attachment:42880724-4152-49f2-93c0-af8c34c12207.png)

# %% [markdown]
# ##Advanced preprocessing - POS(parts of speech)tagging, parsing, coreference resolution

# %% [markdown]
# ![image.png](attachment:66099475-fb09-4252-b9fb-7cd30fea229f.png)
# ![image.png](attachment:1370b735-6757-4581-9045-5986d552d9fe.png)
# ![image.png](attachment:82a614ad-654e-4a26-b52e-98e6f6c4fd5a.png)

# %% [markdown]
# ##Feature Engineering
# Convert text to numbers
# Approaches :
# Ml algo - manual feature engineering
# - have explanations for outcomes
# - have to study about the domain
# - sometimes not relaible
# DL algo - auto feature engineering
# - sometimes do not have explanations
# - not interpretable

# %% [raw]
# ##Modelling
# 1. Applying model/algo ~ modelling
# - heuristic
# -ML algo
# -Dl algo - transfer learning(BERT)
# -cloud API
# How to choose the method of modelling
# -parameters:
# --amount of data
# --nature of problem
# 2. Evaluation
# -Intrensic - technical level - metrics like accuracy confusion matrix etc.
# -Extrensic - business centric

# %% [raw]
# ##Deployment
# -Deploy
# --API(microservices)--chatbot
# -Monitoring
# --Dahboard for performance metrics(KPI)
# -Update
