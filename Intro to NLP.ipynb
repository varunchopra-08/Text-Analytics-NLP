# %% [markdown]
# ![image.png](attachment:82660956-9dd2-4ea1-9316-2c579ecd1724.png)

# %% [markdown]
# ![image.png](attachment:6485d935-527f-4bcc-9da0-2b5a20f4f537.png)

# %% [raw]
# ##Common NLP tasks
#
# Text Document Classification
# Sentiment Analysis
# Information Retrieval
# Parts Of Speech Tagging
# Language Detection and Machine Translation
# Conversational Agents
# Knowledge graph and QA systems
# Text Summarization
# Topic Modelling
# Text Generation
# Spell Check and grammer correction
# Text Parsing
# Speech to Text

# %% [raw]
# ##Approaches to NLP
# Heuristic Methods
# Machine Learning based methods
# deep learning based methods

# %% [raw]
# ##Heuristic Methods
# Regular Expressions
# Wordnet
# Open Mind Common Sense

# %% [raw]
# ##Machine Learning Approach
# ML Workflow
# Algorithms Used
#     Naive Bayes
#     Logistic Regression
#     SVM
#     LDA
#     Hidden Markov Models

# %% [raw]
# ## Deep Learning Approach
# Architecture Used
#     RNN
#     LSTM
#     GRU/CNN
#     Transformers
#     Autoencoders
